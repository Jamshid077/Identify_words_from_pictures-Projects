# %% [markdown]
# <a href="https://colab.research.google.com/github/Jamshidbek077/Identify_words_from_pictures-Projects/blob/master/Image_show_found_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install and Import Dependencies

# %%
# !pip install torch torchvision torchaudio
# !pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 52.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 65.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 19.3 MB/s eta 0:00:00
# ...

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # Read in Images or Video

# %%
image_path='/content/out off2.lpg.jpg'

# %%
reader=easyocr.Reader(['en'],gpu=True)
result=reader.readtext(image_path)
result
# Out:
# [([[79, 45], [275, 45], [275, 107], [79, 107]], 'OUT OF', 0.9650640653806205),
#  ([[61, 119], [293, 119], [293, 183], [61, 183]],
#   'SERVICE',
#   0.9998418463260554)]

# %%
# Out:
# [([[73, 161], [165, 161], [165, 185], [73, 185]],
#   'SERVICE',
#   0.9996239775391538),
#  ([[76, 134], [164, 134], [164, 150], [76, 150]],
#   'TEMPORARILY',
#   0.9651538178064977),
#  ([[76, 144], [164, 144], [164, 168], [76, 168]],
#   'QUT OF',
#   0.3466859770868698)]

# %% [markdown]
# # Drav Results

# %%
top_left=tuple(result[0][0][0])
bottom_right=tuple(result[0][0][2])
text=result[0][1]
font=cv2.FONT_HERSHEY_SIMPLEX

# %%
img=cv2.imread(image_path)
img=cv2.rectangle(img,top_left,bottom_right,(0,255,0),5)
img=cv2.putText(img,text,top_left,font,.5,(255,255,255),2,cv2.LINE_AA)
plt.imshow(img)
plt.show()

# %%
img=cv2.imread(image_path)
for detection in result:
  top_left=tuple([int(val) for val in detection[0][0]])
  bottom_right=tuple([int(val) for val in detection[0][2]])
  text=detection[1]
  font=cv2.FONT_HERSHEY_SIMPLEX
  img=cv2.rectangle(img,top_left,bottom_right,(0,255,0),5)
  img=cv2.putText(img,text,top_left,font,.5,(255,255,255),2,cv2.LINE_AA)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()

# %%
result
# Out:
# [([[79, 45], [275, 45], [275, 107], [79, 107]], 'OUT OF', 0.9650640653806205),
#  ([[61, 119], [293, 119], [293, 183], [61, 183]],
#   'SERVICE',
#   0.9998418463260554)]
